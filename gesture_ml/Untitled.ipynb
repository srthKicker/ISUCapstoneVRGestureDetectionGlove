# %%
# !python predict.py
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775057516.328381    8003 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1775057516.406073    8003 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775057518.210227    8003 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Traceback (most recent call last):
#   File "/media/srth/GamerDisk/VSCodeProjects/ISUCapstoneVRGestureDetectionGlove/gesture_ml/predict.py", line 6, in <module>
#     import serial
# ModuleNotFoundError: No module named 'serial'

# %%
python3 -c "import tensorflow, serial, sklearn, numpy; print('ok')"
# Out:
#   Cell In[2], line 1
#     python3 -c "import tensorflow, serial, sklearn, numpy; print('ok')"
#                ^
# SyntaxError: invalid syntax
